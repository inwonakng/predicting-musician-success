# %%
df = pd.read_json("data/musician-graph/raw_nodes.json")

names_to_num = {n:i for i,n in enumerate(df.name.unique())}

# %%
import pandas as pd

df = pd.read_json('data/musician-graph/raw_nodes.json')
# df.name_1 = df.name_1.map(names_to_num)
# df.name_2 = df.name_2.map(names_to_num)
# df.to_json('data/musician-graph/raw_edges.json')
df.name = df.name.map(names_to_num)
df.to_json('data/musician-graph/raw_nodes.json')

# %%
df
# Out:
#             id   name  isdone               spotifyid  \
# 0       600808      0    True  3TVXtAsR1Inumwj472S9r4
# 1       706819      1    True  6eUKZXaKkcviH0Ku9w2n3V
# 2       823336      2    True  66CXWjxzNUsdJxJ2JdwvnR
# 3      1492430      3    True  4q3ewBCX7sLwd24euuV69X
# 4       796889      4    True  1Xyo4u8uXC1ZmMpatF05PJ
# ...        ...    ...     ...                     ...
# 12900  1418260  22446    True  1ZYRTJCj869ya07OpEAlGR
# 12901   844823  22447    True  1wou9vWv5PgrTn3pu3TydQ
# 12902  1796328  22448    True  2pLu3Ut2C3RviYZ3xUanBs
# 12903   121805  22450    True  0EvGuw8fuWFtxhAsBOFTin
# 12904    11473  22451    True  0BZr6WHaejNA63uhZZZZek
#
#                                                   genres  popularity  \
# 0      ['canadian hip hop', 'canadian pop', 'hip hop'...        98.0
# 1                                      ['pop', 'uk pop']        95.0
# 2                                   ['dance pop', 'pop']        93.0
# ...
